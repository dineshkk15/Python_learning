# %% [markdown]
# <a href="https://colab.research.google.com/github/dineshkk15/hello-world/blob/main/Python_advance/12_Exercise_Trending_Skills.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise - Investigating Trending Skills

# %%
import pandas as pd
import matplotlib.pyplot as plt
import ast
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  object
#  15  job_skills             668704 non-null  object
#  16  job_type_skills        668704 non-null  object
# dtypes: bool(3), datetime64[ns](1), float64(2), object(11)
# memory usage: 86.2+ MB

# %%
type(df['job_skills'][1])
# Out:
# list

# %%
df_da = df[df['job_title_short'] == 'Data Analyst'].copy()

# %%
df_da
# Out:
#        job_title_short  ...                                    job_type_skills
# 1         Data Analyst  ...  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 12        Data Analyst  ...  {'analyst_tools': ['excel', 'power bi', 'sap']...
# 18        Data Analyst  ...  {'analyst_tools': ['excel', 'looker', 'tableau...
# 31        Data Analyst  ...                           {'programming': ['sql']}
# 34        Data Analyst  ...                         {'analyst_tools': ['sap']}
# ...                ...  ...                                                ...
# 785703    Data Analyst  ...                                               None
# 785705    Data Analyst  ...  {'analyst_tools': ['tableau'], 'programming': ...
# 785715    Data Analyst  ...                                               None
# 785717    Data Analyst  ...                        {'cloud': ['aws', 'azure']}
# 785737    Data Analyst  ...  {'analyst_tools': ['sas', 'excel'], 'programmi...
#
# [196075 rows x 17 columns]

# %%
df_da['job_posted_month_no'] = df_da['job_posted_date'].dt.month

df_da
# Out:
#        job_title_short  ... job_posted_month_no
# 1         Data Analyst  ...                   1
# 12        Data Analyst  ...                  12
# 18        Data Analyst  ...                  10
# 31        Data Analyst  ...                  10
# 34        Data Analyst  ...                   2
# ...                ...  ...                 ...
# 785703    Data Analyst  ...                   1
# 785705    Data Analyst  ...                   1
# 785715    Data Analyst  ...                   3
# 785717    Data Analyst  ...                   3
# 785737    Data Analyst  ...                   3
#
# [196075 rows x 18 columns]

# %%
df_da_explode = df_da.explode('job_skills')

df_da_explode
# Out:
#        job_title_short  ... job_posted_month_no
# 1         Data Analyst  ...                   1
# 1         Data Analyst  ...                   1
# 1         Data Analyst  ...                   1
# 1         Data Analyst  ...                   1
# 1         Data Analyst  ...                   1
# ...                ...  ...                 ...
# 785717    Data Analyst  ...                   3
# 785737    Data Analyst  ...                   3
# 785737    Data Analyst  ...                   3
# 785737    Data Analyst  ...                   3
# 785737    Data Analyst  ...                   3
#
# [672513 rows x 18 columns]

# %%
df_da_pivot = df_da_explode.pivot_table(index='job_posted_month_no', columns='job_skills', aggfunc='size', fill_value=0)

df_da_pivot.loc['Total'] = df_da_pivot.sum()

df_da_pivot = df_da_pivot[df_da_pivot.loc['Total'].sort_values(ascending=False).index]

df_da_pivot = df_da_pivot.drop('Total')
df_da_pivot
# Out:
# job_skills             sql  excel  python  ...  capacitor  chainer  msaccess
# job_posted_month_no                        ...
# 1                    11336   8170    6606  ...          1        0         0
# 2                     7947   5772    4751  ...          0        0         0
# 3                     7868   5675    4741  ...          0        0         0
# 4                     7553   5496    4557  ...          0        0         0
# 5                     6617   4773    4070  ...          0        0         1
# 6                     7584   5724    4707  ...          0        0         0
# 7                     7687   5513    4831  ...          0        0         0
# 8                     8823   6482    5576  ...          0        0         0
# 9                     6829   4886    4229  ...          0        0         0
# 10                    7474   5217    4693  ...          0        0         0
# 11                    6652   4776    4233  ...          0        0         0
# 12                    6058   4376    4196  ...          0        1         0
#
# [12 rows x 235 columns]

# %%
df_da_pivot = df_da_pivot.reset_index()
df_da_pivot['job_posted_month'] = df_da_pivot['job_posted_month_no'].apply(lambda x: pd.to_datetime(x, format='%m').strftime('%B'))
df_da_pivot = df_da_pivot.set_index('job_posted_month')
df_da_pivot = df_da_pivot.drop(columns='job_posted_month_no')

# %%
df_da_pivot.iloc[:, :5].plot(kind='line')
plt.title('Top 5 Skills for Data Analysts per month')
plt.xlabel('')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Topics Covered
#
# This exercise goes over:
#
# * Applying Functions
# * Exploding
# * Pivoting
# * Plotting
#
# ## Question
#
# * How are skills trending for Data Analysts on a monthly basis.

# %% [markdown]
# Load data.

# %%
# Importing Libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %% [markdown]
# ### Trends for Data Analyst Jobs

# %% [markdown]
# 1. For this we're going to only be looking at data analyst jobs. So we'll create a copy of our original DataFrame that filters only for Data Analyst roles.

# %%
df_DA = df[df['job_title_short'] == 'Data Analyst'].copy()

# %% [markdown]
# 2. Extract the month from the `job_posted_date`.

# %%
df_DA['job_posted_month_no'] = df_DA['job_posted_date'].dt.month

# %% [markdown]
# 3. Explode the `job_skills` column.

# %%
df_DA_explode= df_DA.explode('job_skills')

# %% [markdown]
# 3. Let's pivot the data to get the count (or size) of each skill for each month.

# %%
df_DA_pivot = df_DA_explode.pivot_table(index='job_posted_month_no', columns='job_skills',  aggfunc='size', fill_value=0)

df_DA_pivot
# Out:
# job_skills           airflow  airtable  alteryx  angular  angular.js  ansible  \
# job_posted_month_no
# 1                        196        16      556       60           2       21
# 2                        168         3      452       49           0       16
# 3                        180         4      440       38           0       23
# 4                        160         4      413       22           0        9
# 5                        131         8      308       27           0       21
# 6                        161        14      392       29           0       12
# 7                        210         4      368       17           0        8
# 8                        192         3      410       22           0       12
# 9                        117         4      314       22           0       14
# 10                       174        11      349       38           0       17
# 11                       168         8      296       24           0       19
# 12                       155         8      281       28           0       14
#
# job_skills           apl  arch  asana  asp.net  ...  webex  windows  wire  \
# job_posted_month_no                             ...
# 1                      0     1     26       32  ...     17      229     6
# 2                      1     4     29       14  ...      9      196     6
# 3                      7     1     17       14  ...      7      200     7
# 4                      8    10      9       15  ...      9      183    15
# 5                     10     3      9       21  ...     12      127     3
# 6                      7     3     16       14  ...      7      150    14
# 7                      8     8     19       15  ...      5      160    12
# 8                      9     4     14       11  ...      9      190     9
# 9                      3     8     11       10  ...      4      152     8
# 10                     0     8     11       14  ...      5      150     9
# 11                     0     4      5       11  ...      4      142     4
# 12                     0     9     10       10  ...      6      147     8
#
# job_skills           word  workfront  wrike  wsl  xamarin  yarn  zoom
# job_posted_month_no
# 1                    1782          0     10    7        0    14    97
# 2                    1236          3      3    4        0     3    39
# 3                    1212          1      1    3        1     3    46
# 4                    1177          9      2    1        0     6    28
# 5                     960          3      4    0        0     8    20
# 6                    1225          6      6    0        0     8    28
# 7                    1080          0      3    0        0     5    39
# 8                    1294          0      1    0        0    12    41
# 9                     934          0      2    0        0     5    23
# 10                    995          5      1    0        1     4    42
# 11                    876          1      1    1        0     6    26
# 12                    820          4      5    0        0     2    36
#
# [12 rows x 235 columns]

# %% [markdown]
# 4. We need to sort the skills to be in order of count to make it easier to plot the top X.

# %%
# Create a total row
df_DA_pivot.loc['Total'] = df_DA_pivot.sum()
# Order columns by total count
df_DA_pivot = df_DA_pivot[df_DA_pivot.loc['Total'].sort_values(ascending=False).index]
# Drop total row
df_DA_pivot = df_DA_pivot.drop('Total')

df_DA_pivot
# Out:
# job_skills             sql  excel  python  tableau  power bi     r   sas  \
# job_posted_month_no
# 1                    11398   8221    6630     5623      4332  3631  3838
# 2                     7919   5741    4734     3943      3282  2581  2614
# 3                     7907   5722    4785     4074      3175  2651  2570
# 4                     7582   5487    4557     3766      3113  2392  2618
# 5                     6627   4778    4068     3242      2708  2095  1940
# 6                     7546   5707    4685     3805      3280  2442  2164
# 7                     7687   5499    4824     3917      3347  2424  2120
# 8                     8829   6471    5589     4521      3849  2958  2566
# 9                     6829   4880    4242     3450      3129  2187  1854
# 10                    7481   5234    4674     3721      3328  2347  2130
# 11                    6600   4757    4243     3257      2994  2182  1738
# 12                    6223   4534    4295     3235      2931  2185  1916
#
# job_skills           powerpoint  word   sap  ...  mattermost  xamarin  gtx  \
# job_posted_month_no                          ...
# 1                          1868  1782  1247  ...           0        0    0
# 2                          1286  1236   973  ...           0        0    0
# 3                          1279  1212   894  ...           0        1    0
# 4                          1202  1177   935  ...           0        0    0
# 5                           976   960   853  ...           0        0    0
# 6                          1175  1225   979  ...           0        0    0
# 7                          1087  1080  1003  ...           0        0    1
# 8                          1341  1294  1108  ...           0        0    0
# 9                           940   934   848  ...           0        0    0
# 10                          963   995   875  ...           1        1    0
# 11                          878   876   809  ...           1        0    0
# 12                          853   820   773  ...           0        0    0
#
# job_skills           suse  nuxt.js  ovh  capacitor  esquisse  chainer  \
# job_posted_month_no
# 1                       0        1    0          1         0        0
# 2                       0        0    0          0         0        0
# 3                       1        0    0          0         0        0
# 4                       0        0    1          0         0        0
# 5                       0        0    0          0         0        0
# 6                       0        0    0          0         0        0
# 7                       0        0    0          0         0        0
# 8                       0        0    0          0         0        0
# 9                       0        0    0          0         0        0
# 10                      0        0    0          0         0        0
# 11                      0        0    0          0         1        0
# 12                      0        0    0          0         0        1
#
# job_skills           msaccess
# job_posted_month_no
# 1                           0
# 2                           0
# 3                           0
# 4                           0
# 5                           1
# 6                           0
# 7                           0
# 8                           0
# 9                           0
# 10                          0
# 11                          0
# 12                          0
#
# [12 rows x 235 columns]

# %% [markdown]
# 5. (Optional) I like to have my months as names, not numbers, so let's change this.

# %%
# code snippet from `6_Exercise_Job_Demand.ipynb`
df_DA_pivot = df_DA_pivot.reset_index()
df_DA_pivot['job_posted_month'] = df_DA_pivot['job_posted_month_no'].apply(lambda x: pd.to_datetime(x, format='%m').strftime('%b'))
df_DA_pivot = df_DA_pivot.set_index('job_posted_month')
df_DA_pivot = df_DA_pivot.drop(columns='job_posted_month_no')

df_DA_pivot
# Out:
# job_skills          sql  excel  python  tableau  power bi     r   sas  \
# job_posted_month
# Jan               11398   8221    6630     5623      4332  3631  3838
# Feb                7919   5741    4734     3943      3282  2581  2614
# Mar                7907   5722    4785     4074      3175  2651  2570
# Apr                7582   5487    4557     3766      3113  2392  2618
# May                6627   4778    4068     3242      2708  2095  1940
# Jun                7546   5707    4685     3805      3280  2442  2164
# Jul                7687   5499    4824     3917      3347  2424  2120
# Aug                8829   6471    5589     4521      3849  2958  2566
# Sep                6829   4880    4242     3450      3129  2187  1854
# Oct                7481   5234    4674     3721      3328  2347  2130
# Nov                6600   4757    4243     3257      2994  2182  1738
# Dec                6223   4534    4295     3235      2931  2185  1916
#
# job_skills        powerpoint  word   sap  ...  mattermost  xamarin  gtx  suse  \
# job_posted_month                          ...
# Jan                     1868  1782  1247  ...           0        0    0     0
# Feb                     1286  1236   973  ...           0        0    0     0
# Mar                     1279  1212   894  ...           0        1    0     1
# Apr                     1202  1177   935  ...           0        0    0     0
# May                      976   960   853  ...           0        0    0     0
# Jun                     1175  1225   979  ...           0        0    0     0
# Jul                     1087  1080  1003  ...           0        0    1     0
# Aug                     1341  1294  1108  ...           0        0    0     0
# Sep                      940   934   848  ...           0        0    0     0
# Oct                      963   995   875  ...           1        1    0     0
# Nov                      878   876   809  ...           1        0    0     0
# Dec                      853   820   773  ...           0        0    0     0
#
# job_skills        nuxt.js  ovh  capacitor  esquisse  chainer  msaccess
# job_posted_month
# Jan                     1    0          1         0        0         0
# Feb                     0    0          0         0        0         0
# Mar                     0    0          0         0        0         0
# Apr                     0    1          0         0        0         0
# May                     0    0          0         0        0         1
# Jun                     0    0          0         0        0         0
# Jul                     0    0          0         0        0         0
# Aug                     0    0          0         0        0         0
# Sep                     0    0          0         0        0         0
# Oct                     0    0          0         0        0         0
# Nov                     0    0          0         1        0         0
# Dec                     0    0          0         0        1         0
#
# [12 rows x 235 columns]

# %% [markdown]
# 6. Let's graph the top 5 skills by count.

# %%
df_DA_pivot.iloc[:, :5].plot(kind='line')

plt.title('Top 5 Skills for Data Analysts per Month')
plt.ylabel('Count')
plt.xlabel('')
plt.show()
